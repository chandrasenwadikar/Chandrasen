# %%
def scream():
    print('Hello World')
scream()
# Out:
# Hello World

# %%
def square(num):
    out = num**2
    return(out)

# %%
sq_3 = square (3)
print(sq_3)
# Out:
# 9

# %%
sq_3 = square (2)
print(sq_3)
# Out:
# 8
# None

# %%
def square(num):
    out = num**2
    print(out)

# %%
def square(num):
    out = 2**3
    print(out)

# %%
q= square(4)
print("Q is" +str(q))
# Out:
# 16
# Q isNone

# %%
def factorial (n):
    if n > 1:
        return n * factorial (n-1)
    else:
        return n
fact = factorial (5)
print(fact)
# Out:
# 120

# %%
def addition(*args):
    print (args)
    return(sum(args))
print(addition(4,5,6,7,8,9))
print(addition(1,2))
# Out:
# (4, 5, 6, 7, 8, 9)
# 39
# (1, 2)
# 3

# %%
def proper(some_text):
    some_text = some_text.strip()
    some_text =" ".join([word[0].upper()+word[1:] for word in some_text.split()])
    return(some_text)
captain =proper ("ms Dhoni")
print(captain)
# Out:
# Ms Dhoni

# %% [markdown]
#  join_by_comma =lambda x :','.join(x)

# %%
string_to_list = lambda x: x.split()
print(string_to_list(captain))
print(type(string_to_list))
# Out:
# ['Ms', 'Dhoni']
# <class 'function'>

# %%
product = lambda x,y :x*y
print(product(3,4))
# Out:
# 12

# %%
product = lambda x,y :x>y
print(product(2,3))
# Out:
# False

# %%
x=2
y=3
product = lambda x,y :x>y
print(product(2>3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-81d094895565> in <module>()
#       2 y=3
#       3 product = lambda x,y :x>y
# ----> 4 print(product(2>3))
#
# TypeError: <lambda>() missing 1 required positional argument: 'y'

# %%
def say(message, times = 1):
    print(message * times)

say('Hello')
say('World', 5)
# Out:
# Hello
# WorldWorldWorldWorldWorld

# %%
min = (lambda x, y: x if x < y else y)
min(101*99, 102*98)
# Out:
# 9996

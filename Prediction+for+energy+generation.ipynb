# %% [markdown]
# # Prediction on to generate the power for specified duration

# %% [markdown]
# 1. We can use the all provided data sets
# 2. Analyze the all data sets and apply the Data mining techniques
# 3. Concatinate the data sets based on the commonaly identified observation.
# 4. Apply the train- test split, feature selection, OLS etc.
# 5. Develop the Linear regression model with the multiple iterations , while adding more observations to monitor overall progress , performance of model.
# 6. Select one of the best model ,based on the metrics generated by the model and corresponds on the observations.
# 7. Learn the statistical terminologies to take inferences from it.
# 8. Co relation matrix will help to learn the find out the highly co related attributes within the observations.
# 9. Find out the error term , based on the final model and apply actual v/s prediction result.

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Importing packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
energy = pd.read_csv("C:/Users/Chandrasen1/Desktop/power_actual.csv")

# %%
energy.head()
# Out:
#    Unnamed: 0             datetime  ghi  gti  power
# 0           0  2017-10-01 00:00:00  0.0  0.0    0.0
# 1           1  2017-10-01 00:15:00  0.0  0.0    0.0
# 2           2  2017-10-01 00:30:00  0.0  0.0    0.0
# 3           3  2017-10-01 00:45:00  0.0  0.0    0.0
# 4           4  2017-10-01 01:00:00  0.0  0.0    0.0

# %%
energy.shape
# Out:
# (70080, 5)

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70080 entries, 0 to 70079
# Data columns (total 5 columns):
# Unnamed: 0    70080 non-null int64
# datetime      70080 non-null object
# ghi           35040 non-null float64
# gti           35040 non-null float64
# power         70080 non-null float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.7+ MB

# %%
energy.describe()
# Out:
#          Unnamed: 0      ghi      gti         power
# count  70080.000000  35040.0  35040.0  70080.000000
# mean   35039.500000      0.0      0.0     28.612915
# std    20230.497769      0.0      0.0    498.795887
# min        0.000000      0.0      0.0      0.000000
# 25%    17519.750000      0.0      0.0      0.000000
# 50%    35039.500000      0.0      0.0      0.000000
# 75%    52559.250000      0.0      0.0      5.540000
# max    70079.000000      0.0      0.0  16172.040000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Converting date to Pandas datetime format
energy['datetime'] = pd.to_datetime(energy['datetime'])

# %%
energy.head()
# Out:
#    Unnamed: 0            datetime  ghi  gti  power
# 0           0 2017-10-01 00:00:00  0.0  0.0    0.0
# 1           1 2017-10-01 00:15:00  0.0  0.0    0.0
# 2           2 2017-10-01 00:30:00  0.0  0.0    0.0
# 3           3 2017-10-01 00:45:00  0.0  0.0    0.0
# 4           4 2017-10-01 01:00:00  0.0  0.0    0.0

# %%
energy.isnull().sum()
# Out:
# Unnamed: 0        0
# datetime          0
# ghi           35040
# gti           35040
# power             0
# dtype: int64

# %%
# Checking the percentage of missing values
round(100*(energy.isnull().sum()/len(energy.index)), 2)
# Out:
# Unnamed: 0     0.0
# datetime       0.0
# ghi           50.0
# gti           50.0
# power          0.0
# dtype: float64

# %%
energy = energy[~np.isnan(energy['ghi'])]

# %%
energy = energy[~np.isnan(energy['gti'])]

# %%
# Checking percentage of missing values after removing the missing values
round(100*(energy.isnull().sum()/len(energy.index)), 2)
# Out:
# Unnamed: 0    0.0
# datetime      0.0
# ghi           0.0
# gti           0.0
# power         0.0
# dtype: float64

# %%
wa = pd.read_csv("C:/Users/Chandrasen1/Desktop/weather_actuals.csv")

# %%
wa.head()
# Out:
#    Unnamed: 0  plant_id         datetime_utc       datetime_local  \
# 0           0         1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 1           1         1  2017-09-30 19:30:00  2017-10-01 01:00:00
# 2           2         1  2017-09-30 20:30:00  2017-10-01 02:00:00
# 3           3         1  2017-09-30 21:30:00  2017-10-01 03:00:00
# 4           4         1  2017-09-30 22:30:00  2017-10-01 04:00:00
#
#    cloud_cover  apparent_temperature  temperature  humidity  dew_point  \
# 0          0.0                 26.52           26         1      19.46
# 1          0.0                 28.78           27         1      20.06
# 2          0.0                 26.58           26         1      19.97
# 3          0.0                 23.84           23         1      18.66
# 4          0.0                 24.13           24         1      17.84
#
#    wind_bearing         ...           precip_accumulation  precip_intensity  \
# 0           308         ...                       -9999.0           -9999.0
# 1         -9999         ...                       -9999.0           -9999.0
# 2         -9999         ...                       -9999.0           -9999.0
# 3           270         ...                       -9999.0           -9999.0
# 4         -9999         ...                       -9999.0           -9999.0
#
#    precip_probability  precip_type  visibility              sunrise  \
# 0             -9999.0         rain        3.57  2017-10-01 00:52:02
# 1             -9999.0         rain        3.06  2017-10-01 00:52:02
# 2             -9999.0         rain        3.06  2017-10-01 00:52:02
# 3             -9999.0         rain        3.56  2017-10-01 00:52:02
# 4             -9999.0         rain        3.06  2017-10-01 00:52:02
#
#                 sunset         icon  summary           updated_at
# 0  2017-10-01 12:45:07  clear-night    Clear  2019-07-16 16:37:16
# 1  2017-10-01 12:45:07          fog    Foggy  2019-07-16 16:37:16
# 2  2017-10-01 12:45:07          fog    Foggy  2019-07-16 16:37:16
# 3  2017-10-01 12:45:07  clear-night    Clear  2019-07-16 16:37:16
# 4  2017-10-01 12:45:07          fog    Foggy  2019-07-16 16:37:16
#
# [5 rows x 31 columns]

# %%
wa.shape
# Out:
# (13619, 31)

# %%
wa.describe()
# Out:
#          Unnamed: 0  plant_id   cloud_cover  apparent_temperature  \
# count  13619.000000   13619.0  13619.000000          13619.000000
# mean    6809.000000       1.0   -314.005310             25.944639
# std     3931.610993       0.0   1744.610028             10.469808
# min        0.000000       1.0  -9999.000000              3.140000
# 25%     3404.500000       1.0      0.000000             17.310000
# 50%     6809.000000       1.0      0.000000             25.540000
# 75%    10213.500000       1.0      0.410000             34.580000
# max    13618.000000       1.0      1.000000             49.750000
#
#         temperature      humidity     dew_point  wind_bearing    wind_speed  \
# count  13619.000000  13619.000000  13619.000000  13619.000000  13619.000000
# mean      24.498054      0.537411     11.924626   -498.677363   -540.808704
# std        8.840016      0.498617      9.129459   2557.943872   2267.247300
# min        5.000000      0.000000    -20.560000  -9999.000000  -9999.000000
# 25%       17.000000      0.000000      5.920000     79.000000      1.620000
# 50%       25.000000      1.000000     10.710000    149.000000      2.410000
# 75%       31.000000      1.000000     19.670000    293.000000      3.330000
# max       47.000000      1.000000     28.350000    359.000000      9.730000
#
#        wind_chill      ...          qpf      uv_index    snow     pop  \
# count      3744.0      ...       3744.0  13619.000000  3744.0  3744.0
# mean      -9999.0      ...      -9999.0  -2394.989280 -9999.0 -9999.0
# std           0.0      ...          0.0   4269.320576     0.0     0.0
# min       -9999.0      ...      -9999.0  -9999.000000 -9999.0 -9999.0
# 25%       -9999.0      ...      -9999.0      0.000000 -9999.0 -9999.0
# 50%       -9999.0      ...      -9999.0      0.000000 -9999.0 -9999.0
# 75%       -9999.0      ...      -9999.0      2.000000 -9999.0 -9999.0
# max       -9999.0      ...      -9999.0     12.000000 -9999.0 -9999.0
#
#        fctcode         ozone  precip_accumulation  precip_intensity  \
# count   3744.0  13619.000000               3744.0      13619.000000
# mean   -9999.0  -2187.730797              -9999.0      -2396.367775
# std        0.0   4385.706548                  0.0       4268.545854
# min    -9999.0  -9999.000000              -9999.0      -9999.000000
# 25%    -9999.0    236.900000              -9999.0          0.000000
# 50%    -9999.0    270.800000              -9999.0          0.000000
# 75%    -9999.0    280.800000              -9999.0          0.000000
# max    -9999.0    351.700000              -9999.0          6.220000
#
#        precip_probability    visibility
# count        13619.000000  13619.000000
# mean         -2396.398081   -117.086149
# std           4268.528833   1130.763316
# min          -9999.000000  -9999.000000
# 25%              0.000000      3.540000
# 50%              0.000000     16.090000
# 75%              0.000000     16.090000
# max              0.730000     16.090000
#
# [8 rows x 23 columns]

# %%
wf = pd.read_csv("C:/Users/Chandrasen1/Desktop/weather_forecast.csv")

# %%
wf.head()
# Out:
#    Unnamed: 0  plant_id         datetime_utc       datetime_local  \
# 0           0         1  2019-09-30 18:30:00  2019-10-01 00:00:00
# 1           1         1  2019-09-30 19:30:00  2019-10-01 01:00:00
# 2           2         1  2019-09-30 20:30:00  2019-10-01 02:00:00
# 3           3         1  2019-09-30 21:30:00  2019-10-01 03:00:00
# 4           4         1  2019-09-30 22:30:00  2019-10-01 04:00:00
#
#    cloud_cover  apparent_temperature  temperature  humidity  dew_point  \
# 0         0.35                 26.41           26         1      22.01
# 1         0.43                 25.95           25         1      22.06
# 2         0.48                 25.46           25         1      22.06
# 3         0.49                 24.80           24         1      21.87
# 4         0.49                 23.99           23         1      21.53
#
#    wind_bearing         ...           precip_accumulation  precip_intensity  \
# 0           101         ...                           NaN               0.0
# 1           105         ...                           NaN               0.0
# 2           106         ...                           NaN               0.0
# 3           106         ...                           NaN               0.0
# 4           100         ...                           NaN               0.0
#
#    precip_probability  precip_type  visibility              sunrise  \
# 0                 0.0          NaN       16.09  2019-10-01 00:51:47
# 1                 0.0          NaN       16.09  2019-10-01 00:51:47
# 2                 0.0          NaN       16.09  2019-10-01 00:51:47
# 3                 0.0          NaN       16.09  2019-10-01 00:51:47
# 4                 0.0          NaN       16.09  2019-10-01 00:51:47
#
#                 sunset                 icon        summary  \
# 0  2019-10-01 12:45:42  partly-cloudy-night  Partly Cloudy
# 1  2019-10-01 12:45:42  partly-cloudy-night  Partly Cloudy
# 2  2019-10-01 12:45:42  partly-cloudy-night  Partly Cloudy
# 3  2019-10-01 12:45:42  partly-cloudy-night  Partly Cloudy
# 4  2019-10-01 12:45:42  partly-cloudy-night  Partly Cloudy
#
#             updated_at
# 0  2019-10-02 23:32:38
# 1  2019-10-02 23:32:38
# 2  2019-10-02 23:32:38
# 3  2019-10-02 23:32:38
# 4  2019-10-02 23:32:38
#
# [5 rows x 31 columns]

# %%
wf.shape
# Out:
# (648, 31)

# %%
wf.describe()
# Out:
#        Unnamed: 0  plant_id  cloud_cover  apparent_temperature  temperature  \
# count  648.000000     648.0   648.000000            648.000000   648.000000
# mean   323.500000       1.0     0.140340             27.562423    27.302469
# std    187.205769       0.0     0.273487              4.596587     4.535063
# min      0.000000       1.0     0.000000             18.300000    18.000000
# 25%    161.750000       1.0     0.000000             23.817500    24.000000
# 50%    323.500000       1.0     0.000000             27.155000    27.000000
# 75%    485.250000       1.0     0.110000             31.942500    32.000000
# max    647.000000       1.0     1.000000             36.340000    36.000000
#
#          humidity   dew_point  wind_bearing  wind_speed  wind_chill  \
# count  648.000000  648.000000    648.000000  648.000000         0.0
# mean     0.513889   14.789244    144.282407    2.214614         NaN
# std      0.500193    3.616508    116.665398    0.756552         NaN
# min      0.000000    2.950000      0.000000    0.600000         NaN
# 25%      0.000000   12.620000     51.750000    1.700000         NaN
# 50%      1.000000   14.900000    109.000000    2.175000         NaN
# 75%      1.000000   17.182500    273.500000    2.682500         NaN
# max      1.000000   22.350000    359.000000    4.430000         NaN
#
#            ...       qpf    uv_index  snow  pop  fctcode       ozone  \
# count      ...       0.0  648.000000   0.0  0.0      0.0  648.000000
# mean       ...       NaN    1.591049   NaN  NaN      NaN  275.790432
# std        ...       NaN    2.451580   NaN  NaN      NaN    3.228630
# min        ...       NaN    0.000000   NaN  NaN      NaN  262.800000
# 25%        ...       NaN    0.000000   NaN  NaN      NaN  274.300000
# 50%        ...       NaN    0.000000   NaN  NaN      NaN  276.100000
# 75%        ...       NaN    3.000000   NaN  NaN      NaN  277.600000
# max        ...       NaN    8.000000   NaN  NaN      NaN  284.900000
#
#        precip_accumulation  precip_intensity  precip_probability    visibility
# count                  0.0        648.000000          648.000000  6.480000e+02
# mean                   NaN          0.007608            0.002423  1.609000e+01
# std                    NaN          0.032064            0.006543  1.102192e-13
# min                    NaN          0.000000            0.000000  1.609000e+01
# 25%                    NaN          0.000000            0.000000  1.609000e+01
# 50%                    NaN          0.000000            0.000000  1.609000e+01
# 75%                    NaN          0.000000            0.000000  1.609000e+01
# max                    NaN          0.420000            0.060000  1.609000e+01
#
# [8 rows x 23 columns]

# %% [markdown]
# ### Combining all data files into one consolidated dataframe

# %%
# Merging on 'customerID'
df = pd.merge(wa, wf, how='inner', on='temperature')

# %%
df.head()
# Out:
#    Unnamed: 0_x  plant_id_x       datetime_utc_x     datetime_local_x  \
# 0             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 1             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 2             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 3             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 4             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
#
#    cloud_cover_x  apparent_temperature_x  temperature  humidity_x  \
# 0            0.0                   26.52           26           1
# 1            0.0                   26.52           26           1
# 2            0.0                   26.52           26           1
# 3            0.0                   26.52           26           1
# 4            0.0                   26.52           26           1
#
#    dew_point_x  wind_bearing_x         ...           precip_accumulation_y  \
# 0        19.46             308         ...                             NaN
# 1        19.46             308         ...                             NaN
# 2        19.46             308         ...                             NaN
# 3        19.46             308         ...                             NaN
# 4        19.46             308         ...                             NaN
#
#    precip_intensity_y  precip_probability_y  precip_type_y  visibility_y  \
# 0                0.00                  0.00            NaN         16.09
# 1                0.00                  0.00            NaN         16.09
# 2                0.00                  0.00            NaN         16.09
# 3                0.00                  0.00            NaN         16.09
# 4                0.05                  0.01           rain         16.09
#
#              sunrise_y             sunset_y               icon_y  \
# 0  2019-10-01 00:51:47  2019-10-01 12:45:42  partly-cloudy-night
# 1  2019-10-01 00:51:47  2019-10-01 12:45:42          clear-night
# 2  2019-10-02 00:52:19  2019-10-02 12:44:31          clear-night
# 3  2019-10-02 00:52:19  2019-10-02 12:44:31          clear-night
# 4  2019-10-02 00:52:19  2019-10-02 12:44:31            clear-day
#
#        summary_y         updated_at_y
# 0  Partly Cloudy  2019-10-02 23:32:38
# 1          Clear  2019-10-02 23:32:38
# 2          Clear  2019-10-03 23:32:40
# 3          Clear  2019-10-03 23:32:40
# 4          Clear  2019-10-03 23:32:40
#
# [5 rows x 61 columns]

# %%
df.describe()
# Out:
#         Unnamed: 0_x  plant_id_x  cloud_cover_x  apparent_temperature_x  \
# count  317905.000000    317905.0  317905.000000           317905.000000
# mean     7058.332077         1.0    -166.839072               29.581311
# std      4153.966795         0.0    1281.830665                6.528744
# min         0.000000         1.0   -9999.000000               17.500000
# 25%      3972.000000         1.0       0.000000               24.130000
# 50%      6240.000000         1.0       0.020000               28.480000
# 75%     10977.000000         1.0       0.550000               34.180000
# max     13618.000000         1.0       1.000000               49.640000
#
#          temperature     humidity_x    dew_point_x  wind_bearing_x  \
# count  317905.000000  317905.000000  317905.000000   317905.000000
# mean       27.583561       0.500986      14.787939     -289.606817
# std         4.349432       0.500000       8.930587     2130.270164
# min        18.000000       0.000000     -20.560000    -9999.000000
# 25%        24.000000       0.000000       7.700000       80.000000
# 50%        27.000000       1.000000      15.580000      136.000000
# 75%        32.000000       1.000000      23.190000      286.000000
# max        36.000000       1.000000      28.350000      359.000000
#
#         wind_speed_x  wind_chill_x      ...       qpf_y     uv_index_y  \
# count  317905.000000       71021.0      ...         0.0  317905.000000
# mean     -406.121777       -9999.0      ...         NaN       1.684632
# std      1980.554733           0.0      ...         NaN       2.502350
# min     -9999.000000       -9999.0      ...         NaN       0.000000
# 25%         1.810000       -9999.0      ...         NaN       0.000000
# 50%         2.570000       -9999.0      ...         NaN       0.000000
# 75%         3.480000       -9999.0      ...         NaN       3.000000
# max         9.730000       -9999.0      ...         NaN       8.000000
#
#        snow_y  pop_y  fctcode_y        ozone_y  precip_accumulation_y  \
# count     0.0    0.0        0.0  317905.000000                    0.0
# mean      NaN    NaN        NaN     275.807003                    NaN
# std       NaN    NaN        NaN       3.240178                    NaN
# min       NaN    NaN        NaN     262.800000                    NaN
# 25%       NaN    NaN        NaN     274.300000                    NaN
# 50%       NaN    NaN        NaN     276.100000                    NaN
# 75%       NaN    NaN        NaN     277.600000                    NaN
# max       NaN    NaN        NaN     284.900000                    NaN
#
#        precip_intensity_y  precip_probability_y  visibility_y
# count       317905.000000         317905.000000  3.179050e+05
# mean             0.007894              0.002472  1.609000e+01
# std              0.033420              0.006703  7.291956e-11
# min              0.000000              0.000000  1.609000e+01
# 25%              0.000000              0.000000  1.609000e+01
# 50%              0.000000              0.000000  1.609000e+01
# 75%              0.000000              0.000000  1.609000e+01
# max              0.420000              0.060000  1.609000e+01
#
# [8 rows x 45 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0_x                   0
# plant_id_x                     0
# datetime_utc_x                 0
# datetime_local_x               0
# cloud_cover_x                  0
# apparent_temperature_x         0
# temperature                    0
# humidity_x                     0
# dew_point_x                    0
# wind_bearing_x                 0
# wind_speed_x                   0
# wind_chill_x              246884
# wind_gust_x                    0
# heat_index_x              246884
# pressure_x                     0
# qpf_x                     246884
# uv_index_x                     0
# snow_x                    246884
# pop_x                     246884
# fctcode_x                 246884
# ozone_x                        0
# precip_accumulation_x     246884
# precip_intensity_x             0
# precip_probability_x           0
# precip_type_x             166212
# visibility_x                   0
# sunrise_x                      0
# sunset_x                       0
# icon_x                         0
# summary_x                      0
#                            ...
# Unnamed: 0_y                   0
# plant_id_y                     0
# datetime_utc_y                 0
# datetime_local_y               0
# cloud_cover_y                  0
# apparent_temperature_y         0
# humidity_y                     0
# dew_point_y                    0
# wind_bearing_y                 0
# wind_speed_y                   0
# wind_chill_y              317905
# wind_gust_y                    0
# heat_index_y              317905
# pressure_y                     0
# qpf_y                     317905
# uv_index_y                     0
# snow_y                    317905
# pop_y                     317905
# fctcode_y                 317905
# ozone_y                        0
# precip_accumulation_y     317905
# precip_intensity_y             0
# precip_probability_y           0
# precip_type_y             261882
# visibility_y                   0
# sunrise_y                      0
# sunset_y                       0
# icon_y                         0
# summary_y                      0
# updated_at_y                   0
# Length: 61, dtype: int64

# %%
# Checking the percentage of missing values
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Unnamed: 0_x                0.00
# plant_id_x                  0.00
# datetime_utc_x              0.00
# datetime_local_x            0.00
# cloud_cover_x               0.00
# apparent_temperature_x      0.00
# temperature                 0.00
# humidity_x                  0.00
# dew_point_x                 0.00
# wind_bearing_x              0.00
# wind_speed_x                0.00
# wind_chill_x               77.66
# wind_gust_x                 0.00
# heat_index_x               77.66
# pressure_x                  0.00
# qpf_x                      77.66
# uv_index_x                  0.00
# snow_x                     77.66
# pop_x                      77.66
# fctcode_x                  77.66
# ozone_x                     0.00
# precip_accumulation_x      77.66
# precip_intensity_x          0.00
# precip_probability_x        0.00
# precip_type_x              52.28
# visibility_x                0.00
# sunrise_x                   0.00
# sunset_x                    0.00
# icon_x                      0.00
# summary_x                   0.00
#                            ...
# Unnamed: 0_y                0.00
# plant_id_y                  0.00
# datetime_utc_y              0.00
# datetime_local_y            0.00
# cloud_cover_y               0.00
# apparent_temperature_y      0.00
# humidity_y                  0.00
# dew_point_y                 0.00
# wind_bearing_y              0.00
# wind_speed_y                0.00
# wind_chill_y              100.00
# wind_gust_y                 0.00
# heat_index_y              100.00
# pressure_y                  0.00
# qpf_y                     100.00
# uv_index_y                  0.00
# snow_y                    100.00
# pop_y                     100.00
# fctcode_y                 100.00
# ozone_y                     0.00
# precip_accumulation_y     100.00
# precip_intensity_y          0.00
# precip_probability_y        0.00
# precip_type_y              82.38
# visibility_y                0.00
# sunrise_y                   0.00
# sunset_y                    0.00
# icon_y                      0.00
# summary_y                   0.00
# updated_at_y                0.00
# Length: 61, dtype: float64

# %% [markdown]
# #### Handling the missing, NA values

# %%
df = df[~np.isnan(df['wind_chill_x'])]
df = df[~np.isnan(df['heat_index_x'])]
df = df[~np.isnan(df['qpf_x'])]
df = df[~np.isnan(df['snow_x'])]
df = df[~np.isnan(df['pop_x'])]
df = df[~np.isnan(df['pop_x'])]
df = df[~np.isnan(df['fctcode_x'])]
df = df[~np.isnan(df['precip_accumulation_x'])]
#df = df[~np.isnan(df['precip_type_x'])]
#df = df[~np.isnan(df['precip_type_y'])]

# %%
# Checking the percentage of missing values
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Unnamed: 0_x                0.00
# plant_id_x                  0.00
# datetime_utc_x              0.00
# datetime_local_x            0.00
# cloud_cover_x               0.00
# apparent_temperature_x      0.00
# temperature                 0.00
# humidity_x                  0.00
# dew_point_x                 0.00
# wind_bearing_x              0.00
# wind_speed_x                0.00
# wind_chill_x                0.00
# wind_gust_x                 0.00
# heat_index_x                0.00
# pressure_x                  0.00
# qpf_x                       0.00
# uv_index_x                  0.00
# snow_x                      0.00
# pop_x                       0.00
# fctcode_x                   0.00
# ozone_x                     0.00
# precip_accumulation_x       0.00
# precip_intensity_x          0.00
# precip_probability_x        0.00
# precip_type_x               0.00
# visibility_x                0.00
# sunrise_x                   0.00
# sunset_x                    0.00
# icon_x                      0.00
# summary_x                   0.00
#                            ...
# Unnamed: 0_y                0.00
# plant_id_y                  0.00
# datetime_utc_y              0.00
# datetime_local_y            0.00
# cloud_cover_y               0.00
# apparent_temperature_y      0.00
# humidity_y                  0.00
# dew_point_y                 0.00
# wind_bearing_y              0.00
# wind_speed_y                0.00
# wind_chill_y              100.00
# wind_gust_y                 0.00
# heat_index_y              100.00
# pressure_y                  0.00
# qpf_y                     100.00
# uv_index_y                  0.00
# snow_y                    100.00
# pop_y                     100.00
# fctcode_y                 100.00
# ozone_y                     0.00
# precip_accumulation_y     100.00
# precip_intensity_y          0.00
# precip_probability_y        0.00
# precip_type_y              84.16
# visibility_y                0.00
# sunrise_y                   0.00
# sunset_y                    0.00
# icon_y                      0.00
# summary_y                   0.00
# updated_at_y                0.00
# Length: 61, dtype: float64

# %% [markdown]
# ### Dropping the observations which have 100% null significance

# %%
df.drop('wind_chill_y', axis=1, inplace=True)

# %%
df.drop('heat_index_y', axis=1, inplace=True)

# %%
df.drop('qpf_y', axis=1, inplace=True)

# %%
df.drop('snow_y', axis=1, inplace=True)

# %%
df.drop('pop_y', axis=1, inplace=True)

# %%
df.drop('fctcode_y', axis=1, inplace=True)

# %%
df.drop('precip_accumulation_y', axis=1, inplace=True)

# %%
df.drop('precip_type_y', axis=1, inplace=True)

# %%
# Checking the percentage of missing values
round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# Unnamed: 0_x              0.0
# plant_id_x                0.0
# datetime_utc_x            0.0
# datetime_local_x          0.0
# cloud_cover_x             0.0
# apparent_temperature_x    0.0
# temperature               0.0
# humidity_x                0.0
# dew_point_x               0.0
# wind_bearing_x            0.0
# wind_speed_x              0.0
# wind_chill_x              0.0
# wind_gust_x               0.0
# heat_index_x              0.0
# pressure_x                0.0
# qpf_x                     0.0
# uv_index_x                0.0
# snow_x                    0.0
# pop_x                     0.0
# fctcode_x                 0.0
# ozone_x                   0.0
# precip_accumulation_x     0.0
# precip_intensity_x        0.0
# precip_probability_x      0.0
# precip_type_x             0.0
# visibility_x              0.0
# sunrise_x                 0.0
# sunset_x                  0.0
# icon_x                    0.0
# summary_x                 0.0
# updated_at_x              0.0
# Unnamed: 0_y              0.0
# plant_id_y                0.0
# datetime_utc_y            0.0
# datetime_local_y          0.0
# cloud_cover_y             0.0
# apparent_temperature_y    0.0
# humidity_y                0.0
# dew_point_y               0.0
# wind_bearing_y            0.0
# wind_speed_y              0.0
# wind_gust_y               0.0
# pressure_y                0.0
# uv_index_y                0.0
# ozone_y                   0.0
# precip_intensity_y        0.0
# precip_probability_y      0.0
# visibility_y              0.0
# sunrise_y                 0.0
# sunset_y                  0.0
# icon_y                    0.0
# summary_y                 0.0
# updated_at_y              0.0
# dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0_x  plant_id_x       datetime_utc_x     datetime_local_x  \
# 0             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 1             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 2             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 3             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 4             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
#
#    cloud_cover_x  apparent_temperature_x  temperature  humidity_x  \
# 0            0.0                   26.52           26           1
# 1            0.0                   26.52           26           1
# 2            0.0                   26.52           26           1
# 3            0.0                   26.52           26           1
# 4            0.0                   26.52           26           1
#
#    dew_point_x  wind_bearing_x         ...           uv_index_y  ozone_y  \
# 0        19.46             308         ...                    0    268.6
# 1        19.46             308         ...                    0    276.1
# 2        19.46             308         ...                    0    275.6
# 3        19.46             308         ...                    0    275.6
# 4        19.46             308         ...                    1    278.6
#
#    precip_intensity_y  precip_probability_y  visibility_y  \
# 0                0.00                  0.00         16.09
# 1                0.00                  0.00         16.09
# 2                0.00                  0.00         16.09
# 3                0.00                  0.00         16.09
# 4                0.05                  0.01         16.09
#
#              sunrise_y             sunset_y               icon_y  \
# 0  2019-10-01 00:51:47  2019-10-01 12:45:42  partly-cloudy-night
# 1  2019-10-01 00:51:47  2019-10-01 12:45:42          clear-night
# 2  2019-10-02 00:52:19  2019-10-02 12:44:31          clear-night
# 3  2019-10-02 00:52:19  2019-10-02 12:44:31          clear-night
# 4  2019-10-02 00:52:19  2019-10-02 12:44:31            clear-day
#
#        summary_y         updated_at_y
# 0  Partly Cloudy  2019-10-02 23:32:38
# 1          Clear  2019-10-02 23:32:38
# 2          Clear  2019-10-03 23:32:40
# 3          Clear  2019-10-03 23:32:40
# 4          Clear  2019-10-03 23:32:40
#
# [5 rows x 53 columns]

# %%
# Plotting boxplot to check the defined variables and significance with respect to different statistical points.
plt.figure(figsize=(300,80))
sns.boxplot(x = 'updated_at_y', y='temperature',hue ='wind_bearing_x',data =df)
plt.show()

# %%
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import r2_score

# %% [markdown]
# ### Splitting the data into train-test

# %%
np.random.seed(0)
df_train,df_test = train_test_split(df, train_size=0.7,test_size=0.3,random_state = 100)
print(df_train.shape)
print(df_test.shape)
# Out:
# (49714, 53)
# (21307, 53)

# %%
df.head()
# Out:
#    Unnamed: 0_x  plant_id_x       datetime_utc_x     datetime_local_x  \
# 0             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 1             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 2             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 3             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
# 4             0           1  2017-09-30 18:30:00  2017-10-01 00:00:00
#
#    cloud_cover_x  apparent_temperature_x  temperature  humidity_x  \
# 0            0.0                   26.52           26           1
# 1            0.0                   26.52           26           1
# 2            0.0                   26.52           26           1
# 3            0.0                   26.52           26           1
# 4            0.0                   26.52           26           1
#
#    dew_point_x  wind_bearing_x         ...           uv_index_y  ozone_y  \
# 0        19.46             308         ...                    0    268.6
# 1        19.46             308         ...                    0    276.1
# 2        19.46             308         ...                    0    275.6
# 3        19.46             308         ...                    0    275.6
# 4        19.46             308         ...                    1    278.6
#
#    precip_intensity_y  precip_probability_y  visibility_y  \
# 0                0.00                  0.00         16.09
# 1                0.00                  0.00         16.09
# 2                0.00                  0.00         16.09
# 3                0.00                  0.00         16.09
# 4                0.05                  0.01         16.09
#
#              sunrise_y             sunset_y               icon_y  \
# 0  2019-10-01 00:51:47  2019-10-01 12:45:42  partly-cloudy-night
# 1  2019-10-01 00:51:47  2019-10-01 12:45:42          clear-night
# 2  2019-10-02 00:52:19  2019-10-02 12:44:31          clear-night
# 3  2019-10-02 00:52:19  2019-10-02 12:44:31          clear-night
# 4  2019-10-02 00:52:19  2019-10-02 12:44:31            clear-day
#
#        summary_y         updated_at_y
# 0  Partly Cloudy  2019-10-02 23:32:38
# 1          Clear  2019-10-02 23:32:38
# 2          Clear  2019-10-03 23:32:40
# 3          Clear  2019-10-03 23:32:40
# 4          Clear  2019-10-03 23:32:40
#
# [5 rows x 53 columns]

# %% [markdown]
# ### Rescaling the features

# %%
scaler = MinMaxScaler()

num_vars = ['cloud_cover_x','apparent_temperature_x','temperature','humidity_x','dew_point_x','wind_bearing_x','uv_index_y',
             'ozone_y','precip_intensity_y','precip_probability_y','visibility_y']

# Fit on data

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])
df_train.head()
# Out:
#         Unnamed: 0_x  plant_id_x       datetime_utc_x     datetime_local_x  \
# 47452           1386           1  2017-11-27 12:30:00  2017-11-27 18:00:00
# 222586          3612           1  2018-03-07 06:30:00  2018-03-07 12:00:00
# 117087          3524           1  2018-02-24 14:30:00  2018-02-24 20:00:00
# 255026           180           1  2017-10-08 06:30:00  2017-10-08 12:00:00
# 136102            10           1  2017-10-01 04:30:00  2017-10-01 10:00:00
#
#         cloud_cover_x  apparent_temperature_x  temperature  humidity_x  \
# 47452        0.999903                0.244681     0.277778         0.0
# 222586       0.999900                0.515957     0.555556         0.0
# 117087       0.999939                0.364603     0.388889         1.0
# 255026       0.999900                0.869439     0.833333         0.0
# 136102       0.999900                0.701644     0.722222         0.0
#
#         dew_point_x  wind_bearing_x         ...           uv_index_y  \
# 47452      0.482611        0.993049         ...                0.000
# 222586     0.374410        0.994014         ...                0.375
# 117087     0.740661        0.975768         ...                0.000
# 255026     0.893517        0.967851         ...                0.250
# 136102     0.835122        0.992470         ...                0.750
#
#          ozone_y  precip_intensity_y  precip_probability_y  visibility_y  \
# 47452   0.647059            0.023810              0.166667           0.0
# 222586  0.529412            0.190476              0.500000           0.0
# 117087  0.687783            0.000000              0.000000           0.0
# 255026  0.438914            0.000000              0.000000           0.0
# 136102  0.380090            0.047619              0.166667           0.0
#
#                   sunrise_y             sunset_y             icon_y  \
# 47452   2019-10-12 00:57:52  2019-10-12 12:33:01          clear-day
# 222586  2019-10-04 00:53:23  2019-10-04 12:42:09             cloudy
# 117087  2019-10-09 00:56:08  2019-10-09 12:36:22        clear-night
# 255026  2019-10-01 00:51:47  2019-10-01 12:45:42  partly-cloudy-day
# 136102  2019-10-01 00:51:47  2019-10-01 12:45:42  partly-cloudy-day
#
#             summary_y         updated_at_y
# 47452           Clear  2019-10-13 23:33:19
# 222586       Overcast  2019-10-05 23:32:38
# 117087          Clear  2019-10-10 23:32:40
# 255026  Mostly Cloudy  2019-10-02 23:32:38
# 136102  Mostly Cloudy  2019-10-02 23:32:38
#
# [5 rows x 53 columns]

# %%
df_train[num_vars].describe()
# Out:
#        cloud_cover_x  apparent_temperature_x   temperature    humidity_x  \
# count   49714.000000            49714.000000  49714.000000  49714.000000
# mean        0.922833                0.376938      0.395794      0.407491
# std         0.266697                0.199298      0.217038      0.491372
# min         0.000000                0.000000      0.000000      0.000000
# 25%         0.999900                0.236460      0.222222      0.000000
# 50%         0.999900                0.319632      0.333333      0.000000
# 75%         0.999900                0.492263      0.500000      1.000000
# max         1.000000                1.000000      1.000000      1.000000
#
#         dew_point_x  wind_bearing_x    uv_index_y       ozone_y  \
# count  49714.000000    49714.000000  49714.000000  49714.000000
# mean       0.581612        0.786448      0.109687      0.581581
# std        0.229020        0.398657      0.234538      0.146979
# min        0.000000        0.000000      0.000000      0.000000
# 25%        0.373551        0.970168      0.000000      0.511312
# 50%        0.607128        0.991408      0.000000      0.601810
# 75%        0.781022        0.994497      0.125000      0.669683
# max        1.000000        1.000000      1.000000      1.000000
#
#        precip_intensity_y  precip_probability_y  visibility_y
# count        49714.000000          49714.000000       49714.0
# mean             0.014460              0.036878           0.0
# std              0.064867              0.105295           0.0
# min              0.000000              0.000000           0.0
# 25%              0.000000              0.000000           0.0
# 50%              0.000000              0.000000           0.0
# 75%              0.000000              0.000000           0.0
# max              1.000000              1.000000           0.0

# %%
# Check the corelation coefficient to see which variables are highly corelated 

plt.figure(figsize=(50,40))
sns.heatmap(df_train.corr(),annot = True, cmap ="YlGnBu")
plt.show()

# %% [markdown]
# ### Visualize different close co relation observations mostly impacting on enegry generation

# %%
plt.figure(figsize=[6,6])
plt.scatter(df_train.pressure_y, df_train.temperature)
plt.show()

# %%
plt.figure(figsize=[6,6])
plt.scatter(df_train.dew_point_x, df_train.temperature)
plt.show()

# %%
plt.figure(figsize=[6,6])
plt.scatter(df_train.apparent_temperature_x, df_train.temperature)
plt.show()

# %% [markdown]
# ### Dividing into X and Y sets for the model building

# %%
y_train = df_train.pop('temperature')
X_train = df_train

# %%
y_train.head()
# Out:
# 47452     0.277778
# 222586    0.555556
# 117087    0.388889
# 255026    0.833333
# 136102    0.722222
# Name: temperature, dtype: float64

# %%
# Add a constant

X_train_lm = sm.add_constant(X_train[['dew_point_x']])

# create a first fitted model

lr = sm.OLS(y_train,X_train_lm).fit()

# %%
# check the parameters obtained

lr.params
# Out:
# const          0.244312
# dew_point_x    0.260452
# dtype: float64

# %%
# Visualize the data with a scatter plot and fitted regression line

plt.scatter(X_train_lm.iloc[:,1],y_train)
plt.plot(X_train_lm.iloc[:,1],-0.072+1.210*X_train_lm.iloc[:,1],'r')
plt.show()

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            temperature   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     4062.
# Date:                Tue, 27 Oct 2020   Prob (F-statistic):               0.00
# Time:                        20:15:40   Log-Likelihood:                 7358.9
# No. Observations:               49714   AIC:                        -1.471e+04
# Df Residuals:                   49712   BIC:                        -1.470e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.2443      0.003     95.639      0.000       0.239       0.249
# dew_point_x     0.2605      0.004     63.731      0.000       0.252       0.268
# ==============================================================================
# Omnibus:                     3118.208   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3741.625
# Skew:                           0.671   Prob(JB):                         0.00
# Kurtosis:                       2.917   Cond. No.                         5.90
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# adding another variable

X_train_sm = X_train[['pressure_y','apparent_temperature_x','dew_point_x']]
X_train_sm = sm.add_constant(X_train_sm)

# Create a  model

lr=sm.OLS(y_train,X_train_sm)

# fit
lr_model=lr.fit()

# params
lr_model.params
# Out:
# const                     0.261674
# pressure_y               -0.000249
# apparent_temperature_x    1.098790
# dew_point_x              -0.048064
# dtype: float64

# %%
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            temperature   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                 1.415e+06
# Date:                Tue, 27 Oct 2020   Prob (F-statistic):               0.00
# Time:                        20:21:24   Log-Likelihood:             1.1624e+05
# No. Observations:               49714   AIC:                        -2.325e+05
# Df Residuals:                   49710   BIC:                        -2.324e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.2617      0.058      4.527      0.000       0.148       0.375
# pressure_y                -0.0002   5.71e-05     -4.364      0.000      -0.000      -0.000
# apparent_temperature_x     1.0988      0.001   1944.802      0.000       1.098       1.100
# dew_point_x               -0.0481      0.000    -99.481      0.000      -0.049      -0.047
# ==============================================================================
# Omnibus:                    15016.477   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            73050.145
# Skew:                          -1.389   Prob(JB):                         0.00
# Kurtosis:                       8.248   Cond. No.                     5.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# adding another variable

X_train_sm = X_train[['pressure_y','apparent_temperature_x','dew_point_x','wind_bearing_x']]
X_train_sm = sm.add_constant(X_train_sm)

# Create a  model

lr1=sm.OLS(y_train,X_train_sm)

# fit
lr1_model=lr1.fit()

# params
lr1_model.params
# Out:
# const                     0.269309
# pressure_y               -0.000253
# apparent_temperature_x    1.100920
# dew_point_x              -0.051226
# wind_bearing_x           -0.003303
# dtype: float64

# %%
lr1_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            temperature   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.988
# Method:                 Least Squares   F-statistic:                 1.064e+06
# Date:                Tue, 27 Oct 2020   Prob (F-statistic):               0.00
# Time:                        20:58:15   Log-Likelihood:             1.1630e+05
# No. Observations:               49714   AIC:                        -2.326e+05
# Df Residuals:                   49709   BIC:                        -2.325e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.2693      0.058      4.664      0.000       0.156       0.382
# pressure_y                -0.0003    5.7e-05     -4.438      0.000      -0.000      -0.000
# apparent_temperature_x     1.1009      0.001   1837.535      0.000       1.100       1.102
# dew_point_x               -0.0512      0.001    -90.267      0.000      -0.052      -0.050
# wind_bearing_x            -0.0033      0.000    -10.589      0.000      -0.004      -0.003
# ==============================================================================
# Omnibus:                    14635.510   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            70145.070
# Skew:                          -1.356   Prob(JB):                         0.00
# Kurtosis:                       8.149   Cond. No.                     5.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X = df [['cloud_cover_x', 'apparent_temperature_x', 'temperature', 'humidity_x',
       'dew_point_x', 'wind_bearing_x', 'wind_speed_x', 'wind_chill_x',
       'wind_gust_x', 'heat_index_x', 'pressure_x', 'qpf_x', 'uv_index_x',
       'snow_x', 'pop_x', 'fctcode_x', 'ozone_x', 'precip_accumulation_x',
       'precip_intensity_x', 'precip_probability_x','visibility_x','plant_id_y','cloud_cover_y', 'apparent_temperature_y',
       'humidity_y', 'dew_point_y', 'wind_bearing_y', 'wind_speed_y',
       'wind_gust_y', 'pressure_y', 'uv_index_y', 'ozone_y',
       'precip_intensity_y', 'visibility_y']]

y = df['temperature']

# %%
X =sm.add_constant(X)
lm_3 = sm.OLS(y,X).fit()
print(lm_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            temperature   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.689e+22
# Date:                Tue, 27 Oct 2020   Prob (F-statistic):               0.00
# Time:                        21:15:43   Log-Likelihood:             1.3807e+06
# No. Observations:               71021   AIC:                        -2.761e+06
# Df Residuals:                   70995   BIC:                        -2.761e+06
# Df Model:                          25
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# cloud_cover_x           1.092e-16   1.34e-15      0.082      0.935   -2.51e-15    2.73e-15
# apparent_temperature_x -6.038e-12   7.61e-12     -0.793      0.428    -2.1e-11    8.88e-12
# temperature                1.0000    1.1e-11   9.08e+10      0.000       1.000       1.000
# humidity_x             -3.666e-12   1.24e-11     -0.296      0.767   -2.79e-11    2.06e-11
# dew_point_x             5.386e-13   1.23e-12      0.438      0.661   -1.87e-12    2.95e-12
# wind_bearing_x         -8.349e-16   2.25e-15     -0.371      0.710   -5.24e-15    3.57e-15
# wind_speed_x            2.992e-16   2.34e-15      0.128      0.898    -4.3e-15    4.89e-15
# wind_chill_x            4.206e-11   3.14e-14   1341.480      0.000     4.2e-11    4.21e-11
# wind_gust_x              4.73e-14   6.53e-12      0.007      0.994   -1.28e-11    1.28e-11
# heat_index_x           -8.282e-12   3.14e-14   -264.154      0.000   -8.34e-12   -8.22e-12
# pressure_x              2.648e-16   7.49e-16      0.353      0.724    -1.2e-15    1.73e-15
# qpf_x                  -6.744e-12   3.14e-14   -215.124      0.000   -6.81e-12   -6.68e-12
# uv_index_x              1.155e-14   3.26e-12      0.004      0.997   -6.39e-12    6.41e-12
# snow_x                 -6.749e-12   3.14e-14   -215.273      0.000   -6.81e-12   -6.69e-12
# pop_x                  -6.834e-12   3.14e-14   -217.983      0.000    -6.9e-12   -6.77e-12
# fctcode_x              -6.731e-12   3.14e-14   -214.702      0.000   -6.79e-12   -6.67e-12
# ozone_x                 1.515e-14   8.22e-13      0.018      0.985    -1.6e-12    1.63e-12
# precip_accumulation_x  -6.719e-12   3.14e-14   -214.306      0.000   -6.78e-12   -6.66e-12
# precip_intensity_x      3.055e-13   6.52e-10      0.000      1.000   -1.28e-09    1.28e-09
# precip_probability_x   -2.842e-13   6.51e-10     -0.000      1.000   -1.28e-09    1.28e-09
# visibility_x           -6.287e-17   1.78e-15     -0.035      0.972   -3.55e-15    3.43e-15
# plant_id_y              4.049e-16   3.14e-18    129.134      0.000    3.99e-16    4.11e-16
# cloud_cover_y          -4.197e-14   1.51e-11     -0.003      0.998   -2.97e-11    2.96e-11
# apparent_temperature_y  5.174e-14   7.96e-12      0.007      0.995   -1.55e-11    1.56e-11
# humidity_y              1.465e-14   1.25e-11      0.001      0.999   -2.45e-11    2.45e-11
# dew_point_y             2.931e-14   1.61e-12      0.018      0.985   -3.13e-12    3.19e-12
# wind_bearing_y         -7.663e-15   3.36e-14     -0.228      0.819   -7.34e-14    5.81e-14
# wind_speed_y            2.531e-14   7.73e-12      0.003      0.997   -1.51e-11    1.52e-11
# wind_gust_y             6.217e-15   3.48e-12      0.002      0.999   -6.81e-12    6.83e-12
# pressure_y             -1.898e-14   2.09e-12     -0.009      0.993   -4.11e-12    4.07e-12
# uv_index_y             -1.998e-15   2.53e-12     -0.001      0.999   -4.97e-12    4.96e-12
# ozone_y                 1.227e-14   1.07e-12      0.011      0.991   -2.09e-12    2.12e-12
# precip_intensity_y     -1.297e-13   1.27e-10     -0.001      0.999   -2.49e-10    2.49e-10
# visibility_y            2.229e-14   5.04e-17    441.792      0.000    2.22e-14    2.24e-14
# ==============================================================================
# Omnibus:                    21267.926   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            46314.652
# Skew:                          -1.847   Prob(JB):                         0.00
# Kurtosis:                       4.414   Cond. No.                     1.06e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.1e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Importing RFE and LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
df.columns
# Out:
# Index(['Unnamed: 0_x', 'plant_id_x', 'datetime_utc_x', 'datetime_local_x',
#        'cloud_cover_x', 'apparent_temperature_x', 'temperature', 'humidity_x',
#        'dew_point_x', 'wind_bearing_x', 'wind_speed_x', 'wind_chill_x',
#        'wind_gust_x', 'heat_index_x', 'pressure_x', 'qpf_x', 'uv_index_x',
#        'snow_x', 'pop_x', 'fctcode_x', 'ozone_x', 'precip_accumulation_x',
#        'precip_intensity_x', 'precip_probability_x', 'precip_type_x',
#        'visibility_x', 'sunrise_x', 'sunset_x', 'icon_x', 'summary_x',
#        'updated_at_x', 'Unnamed: 0_y', 'plant_id_y', 'datetime_utc_y',
#        'datetime_local_y', 'cloud_cover_y', 'apparent_temperature_y',
#        'humidity_y', 'dew_point_y', 'wind_bearing_y', 'wind_speed_y',
#        'wind_gust_y', 'pressure_y', 'uv_index_y', 'ozone_y',
#        'precip_intensity_y', 'precip_probability_y', 'visibility_y',
#        'sunrise_y', 'sunset_y', 'icon_y', 'summary_y', 'updated_at_y'],
#       dtype='object')

# %% [markdown]
# ### Predication on Linear Model

# %%
X = df [['cloud_cover_x', 'apparent_temperature_x', 'temperature', 'humidity_x',
       'dew_point_x', 'wind_bearing_x', 'wind_speed_x', 'wind_chill_x',
       'wind_gust_x', 'heat_index_x', 'pressure_x', 'qpf_x', 'uv_index_x',
       'snow_x', 'pop_x', 'fctcode_x', 'ozone_x', 'precip_accumulation_x',
       'precip_intensity_x', 'precip_probability_x','visibility_x','plant_id_y','cloud_cover_y', 'apparent_temperature_y',
       'humidity_y', 'dew_point_y', 'wind_bearing_y', 'wind_speed_y',
       'wind_gust_y', 'pressure_y', 'uv_index_y', 'ozone_y',
       'precip_intensity_y', 'visibility_y']]

X = sm.add_constant(X)
predicated_views = lm_3.predict(X)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(df.temperature, predicated_views)
r_squared = r2_score(df.temperature, predicated_views)

# %% [markdown]
# ### Calculate the R Square and Mean Square Error

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 7.610357512018668e-19
# r_square_value : 1.0

# %% [markdown]
# ### Residual Analysis on final model

# %%
y_train_temperature = lm_3.predict(X)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y - y_train_temperature), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
plt.show()

# %% [markdown]
# ### Save updated dataset

# %%
df.to_csv('df.csv')

# %%
#### Final Dataset file of data frame converted into csv and store it on the location
df.to_csv(r'C:\Users\Chandrasen1\Desktop\Assignement Details\final.csv', index = False)

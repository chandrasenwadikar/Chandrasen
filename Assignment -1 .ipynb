# %% [markdown]
# # Assignment - Analyse based on the data, user reviews and other information of restaurants. To find out useful insights to improve overall restaurant experience in Bengaluru.
# Steps :
# 1. Importing require libraries and packages
# 2. Reading ,understanding and visulaizing the data
# 3. Train the model
# 4. Residual Analysis.
# 5. Test the model
# 6. Predication, model evaulation on the test
#
# Author : Chandrasen Wadikar

# %%
# 1. Importing the require libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')

# set the seaborn style
sns.set_style("whitegrid")

# %%
# 2. Reading the data

rest = pd.read_csv("C:/Users/chandrasen.wadikar/Desktop/RestoInfo.csv")
rest.head()
# Out:
#    Unnamed: 0                          name online_order book_table    rate  \
# 0       46019        Unique Brew Cafe Resto           No         No     NaN
# 1       28849                Jayanthi Sagar           No         No  3.1 /5
# 2       19855  Rock Stone Ice Cream Factory          Yes         No   4.0/5
# 3       35188         Punjabi by Nature 2.0           No         No  4.2 /5
# 4        7070             Rayalaseema Chefs          Yes        Yes   3.9/5
#
#    votes               location                    rest_type  \
# 0      0            Indiranagar                  Quick Bites
# 1     21  Koramangala 5th Block                  Quick Bites
# 2    131                    BTM               Dessert Parlor
# 3   3236                    BTM  Casual Dining, Microbrewery
# 4    225           Marathahalli                Casual Dining
#
#                                           dish_liked  \
# 0                                                NaN
# ...

# %%
# Checking the shape of the data in terms of the rows and columns
rest.shape
# Out:
# (2069, 15)

# %%
# Checking whether any missing values, null present in the data
rest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2069 entries, 0 to 2068
# Data columns (total 15 columns):
# Unnamed: 0                     2069 non-null int64
# name                           2069 non-null object
# online_order                   2069 non-null object
# book_table                     2069 non-null object
# rate                           1770 non-null object
# votes                          2069 non-null int64
# location                       2069 non-null object
# rest_type                      2052 non-null object
# dish_liked                     962 non-null object
# cuisines                       2069 non-null object
# approx_cost(for two people)    2053 non-null object
# reviews_list                   2069 non-null object
# menu_item                      2069 non-null object
# listed_in(type)                2069 non-null object
# listed_in(city)                2069 non-null object
# dtypes: int64(2), object(13)
# memory usage: 242.5+ KB

# %%
# 3. Visulaizing different statistics 
rest.describe()
# Out:
#          Unnamed: 0        votes
# count   2069.000000  2069.000000
# mean   25840.654422   276.048333
# std    14877.311956   673.916908
# min       27.000000     0.000000
# 25%    12561.000000     7.000000
# 50%    26193.000000    43.000000
# 75%    38902.000000   210.000000
# max    51643.000000  7854.000000

# %%
# Visualizing the variables
sns.pairplot(rest)
plt.figure(figsize=(10,5))
plt.show()

# %%
rest.isnull()
# Out:
#       Unnamed: 0   name  online_order  book_table   rate  votes  location  \
# 0          False  False         False       False   True  False     False
# 1          False  False         False       False  False  False     False
# 2          False  False         False       False  False  False     False
# 3          False  False         False       False  False  False     False
# 4          False  False         False       False  False  False     False
# 5          False  False         False       False  False  False     False
# 6          False  False         False       False  False  False     False
# 7          False  False         False       False  False  False     False
# 8          False  False         False       False  False  False     False
# 9          False  False         False       False  False  False     False
# 10         False  False         False       False  False  False     False
# 11         False  False         False       False   True  False     False
# ...

# %%
# Removing NA values
rest_remove = rest.dropna(axis=0)

# %%
# Checking the dimesions
rest_remove.shape
# Out:
# (941, 15)

# %%
# Special charaters, Garbage data is handled with the space.
removeSpecialChars = rest.replace ({ord(c): " " for c in "!@#$%^&*()[]{};:,./<>?\|`~-=_+"})

# %%
rest.isnull().sum()
# Out:
# Unnamed: 0                        0
# name                              0
# online_order                      0
# book_table                        0
# rate                            299
# votes                             0
# location                          0
# rest_type                        17
# dish_liked                     1107
# cuisines                          0
# approx_cost(for two people)      16
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
rest.replace(0," ")
# Out:
#       Unnamed: 0                                     name online_order  \
# 0          46019                   Unique Brew Cafe Resto           No
# 1          28849                           Jayanthi Sagar           No
# 2          19855             Rock Stone Ice Cream Factory          Yes
# 3          35188                    Punjabi by Nature 2.0           No
# 4           7070                        Rayalaseema Chefs          Yes
# 5          32050                               Bistro Oui          Yes
# 6           9918                          Bhavani Upahara          Yes
# 7           6134                   Hotel Tom's Restaurant          Yes
# 8           5350                                 Munchies          Yes
# 9           2301                    Vinaya Coffee Moments          Yes
# 10          6931                               Kaati Zone          Yes
# 11          5526                               Mount Blue           No
# ...

# %%
rest.fillna(rest.mean(), inplace=True)
# count the number of NaN values in each column
print(rest.isnull().sum())
# Out:
# Unnamed: 0                        0
# name                              0
# online_order                      0
# book_table                        0
# rate                            299
# votes                             0
# location                          0
# rest_type                        17
# dish_liked                     1107
# cuisines                          0
# approx_cost(for two people)      16
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
rest.isnull().sum()
# Out:
# Unnamed: 0                        0
# name                              0
# online_order                      0
# book_table                        0
# rate                            299
# votes                             0
# location                          0
# rest_type                        17
# dish_liked                     1107
# cuisines                          0
# approx_cost(for two people)      16
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
rest.head()
# Out:
#    Unnamed: 0                          name online_order book_table    rate  \
# 0       46019        Unique Brew Cafe Resto           No         No     NaN
# 1       28849                Jayanthi Sagar           No         No  3.1 /5
# 2       19855  Rock Stone Ice Cream Factory          Yes         No   4.0/5
# 3       35188         Punjabi by Nature 2.0           No         No  4.2 /5
# 4        7070             Rayalaseema Chefs          Yes        Yes   3.9/5
#
#    votes               location                    rest_type  \
# 0      0            Indiranagar                  Quick Bites
# 1     21  Koramangala 5th Block                  Quick Bites
# 2    131                    BTM               Dessert Parlor
# 3   3236                    BTM  Casual Dining, Microbrewery
# 4    225           Marathahalli                Casual Dining
#
#                                           dish_liked  \
# 0                                                NaN
# ...

# %%
#Handling the null values
rest.fillna("0", inplace = True)

# %%
rest.isnull().sum()
# Out:
# Unnamed: 0                     0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# listed_in(city)                0
# dtype: int64

# %%
rest.head()
# Out:
#    Unnamed: 0                          name online_order book_table    rate  \
# 0       46019        Unique Brew Cafe Resto           No         No       0
# 1       28849                Jayanthi Sagar           No         No  3.1 /5
# 2       19855  Rock Stone Ice Cream Factory          Yes         No   4.0/5
# 3       35188         Punjabi by Nature 2.0           No         No  4.2 /5
# 4        7070             Rayalaseema Chefs          Yes        Yes   3.9/5
#
#    votes               location                    rest_type  \
# 0      0            Indiranagar                  Quick Bites
# 1     21  Koramangala 5th Block                  Quick Bites
# 2    131                    BTM               Dessert Parlor
# 3   3236                    BTM  Casual Dining, Microbrewery
# 4    225           Marathahalli                Casual Dining
#
#                                           dish_liked  \
# 0                                                  0
# ...

# %%
sns.pairplot(rest)
plt.show()

# %%
# Visualizing the categorical  varibales
plt.figure(figsize=(20,12))
plt.subplot(2,3,1)
sns.boxplot(x='votes', y='rate', data= rest)
plt.subplot(2,3,2)
#sns.boxplot(x='book_table', y='rate', data= rest)
#plt.subplot(2,3,3)
#sns.boxplot(x='location', y='rate', data= rest)
#plt.subplot(2,3,4)
#sns.boxplot(x='rest_type', y='rate', data= rest)
#plt.subplot(2,3,5)
#sns.boxplot(x='dish_liked', y='rate', data= rest)
#plt.subplot(2,3,6)
#sns.boxplot(x='cuisines', y='rate', data= rest)
#plt.subplot(2,3,7)
#sns.boxplot(x='reviews_list', y='rate', data= rest)
#plt.subplot(2,3,8)
#sns.boxplot(x='menu_item', y='rate', data= rest)
#plt.subplot(2,3,9)
#sns.boxplot(x='listed_in(type)', y='rate', data= rest)
#plt.subplot(2,3,10)
#sns.boxplot(x='listed_in(city)', y='rate', data= rest)
#plt.subplot(2,3,11)
plt.show()

# %%
### Data Preparation

# List of variables to map

varlist =  ['online_order', 'book_table']

# Defining the map function
def binary_map(x):
    return x.map({'yes': 1, "no": 0})

# Applying the function to the housing list
rest[varlist] = rest[varlist].apply(binary_map)

# %% [raw]
# rest.head()

# %%
# Spliting data into train and test

from sklearn.model_selection import train_test_split

# We specify this so that the train and test data set always have the same rows, respectively
np.random.seed(0)
df_train, df_test = train_test_split(rest, train_size = 0.7, test_size = 0.3, random_state = 100)

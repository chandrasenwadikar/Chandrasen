# %% [markdown]
# # Prediction of benign or malignant cancer tumors

# %% [markdown]
# ###  Importing and Merging Data

# %%
# Importing Pandas and NumPy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wpbc_data = pd.read_csv(r"C:\Users\chandrasen.wadikar\Desktop\sezzle assignment\wpbc.data")

# %%
print(len(wpbc_data))
# Out:
# 197

# %%
wpbc_data.head()
# Out:
#    119513  N   31  18.02   27.6   117.5    1013  0.09489  0.1036  0.1086 ...   \
# 0    8423  N   61  17.99  10.38  122.80  1001.0  0.11840  0.2776  0.3001 ...
# 1  842517  N  116  21.37  17.44  137.50  1373.0  0.08836  0.1189  0.1255 ...
# 2  843483  N  123  11.42  20.38   77.58   386.1  0.14250  0.2839  0.2414 ...
# 3  843584  R   27  20.29  14.34  135.10  1297.0  0.10030  0.1328  0.1980 ...
# 4  843786  R   77  12.75  15.29   84.60   502.7  0.11890  0.1569  0.1664 ...
#
#     139.7    1436  0.1195  0.1926   0.314   0.117  0.2677  0.08113    5  5.1
# 0  184.60  2019.0  0.1622  0.6656  0.7119  0.2654  0.4601  0.11890  3.0    2
# 1  159.10  1949.0  0.1188  0.3449  0.3414  0.2032  0.4334  0.09067  2.5    0
# 2   98.87   567.7  0.2098  0.8663  0.6869  0.2575  0.6638  0.17300  2.0    0
# 3  152.20  1575.0  0.1374  0.2050  0.4000  0.1625  0.2364  0.07678  3.5    0
# 4  107.30   733.2  0.1706  0.4196  0.5999  0.1709  0.3485  0.11790  2.5    0
#
# [5 rows x 35 columns]

# %%
wpbc_data.columns = ['ID Number','Outcome','Time','Realvalued Features1','Realvalued Features2','Realvalued Features3',
                      'Realvalued Features4','Realvalued Features5','Realvalued Features6','Realvalued Features7',
                      'Realvalued Features8','Realvalued Features9','Realvalued Features10','Realvalued Features11','Realvalued Features12','Realvalued Features13','Realvalued Features14','Realvalued Features15','Realvalued Features16','Realvalued Features17','Realvalued Features18','Realvalued Features19','Realvalued Features20','Realvalued Features21','Realvalued Features22','Radius','Texture','Perimeter',
                       'Area','Smoothness','Compactness','Concavity','Concave Points','Symmetry','Fractal Dimension']

# %%
wpbc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 35 columns):
# ID Number                197 non-null int64
# Outcome                  197 non-null object
# Time                     197 non-null int64
# Realvalued Features1     197 non-null float64
# Realvalued Features2     197 non-null float64
# Realvalued Features3     197 non-null float64
# Realvalued Features4     197 non-null float64
# Realvalued Features5     197 non-null float64
# Realvalued Features6     197 non-null float64
# Realvalued Features7     197 non-null float64
# Realvalued Features8     197 non-null float64
# Realvalued Features9     197 non-null float64
# Realvalued Features10    197 non-null float64
# Realvalued Features11    197 non-null float64
# Realvalued Features12    197 non-null float64
# Realvalued Features13    197 non-null float64
# Realvalued Features14    197 non-null float64
# Realvalued Features15    197 non-null float64
# ...

# %% [markdown]
# ### Let's understand strucutre of DataFrame and Null values

# %%
### Checking the percentage of missing values
round(100*(wpbc_data.isnull().sum()/len(wpbc_data.index)), 2)
# Out:
# ID Number                0.0
# Outcome                  0.0
# Time                     0.0
# Realvalued Features1     0.0
# Realvalued Features2     0.0
# Realvalued Features3     0.0
# Realvalued Features4     0.0
# Realvalued Features5     0.0
# Realvalued Features6     0.0
# Realvalued Features7     0.0
# Realvalued Features8     0.0
# Realvalued Features9     0.0
# Realvalued Features10    0.0
# Realvalued Features11    0.0
# Realvalued Features12    0.0
# Realvalued Features13    0.0
# Realvalued Features14    0.0
# Realvalued Features15    0.0
# Realvalued Features16    0.0
# Realvalued Features17    0.0
# Realvalued Features18    0.0
# Realvalued Features19    0.0
# Realvalued Features20    0.0
# Realvalued Features21    0.0
# Realvalued Features22    0.0
# Radius                   0.0
# Texture                  0.0
# Perimeter                0.0
# Area                     0.0
# Smoothness               0.0
# Compactness              0.0
# Concavity                0.0
# ...

# %%
wpbc_data.shape
# Out:
# (197, 35)

# %%
wpbc_data.head()
# Out:
#    ID Number Outcome  Time  Realvalued Features1  Realvalued Features2  \
# 0       8423       N    61                 17.99                 10.38
# 1     842517       N   116                 21.37                 17.44
# 2     843483       N   123                 11.42                 20.38
# 3     843584       R    27                 20.29                 14.34
# 4     843786       R    77                 12.75                 15.29
#
#    Realvalued Features3  Realvalued Features4  Realvalued Features5  \
# 0                122.80                1001.0               0.11840
# 1                137.50                1373.0               0.08836
# 2                 77.58                 386.1               0.14250
# 3                135.10                1297.0               0.10030
# 4                 84.60                 502.7               0.11890
#
#    Realvalued Features6  Realvalued Features7        ...          Radius  \
# ...

# %%
wpbc_data.isnull().sum()
# Out:
# ID Number                0
# Outcome                  0
# Time                     0
# Realvalued Features1     0
# Realvalued Features2     0
# Realvalued Features3     0
# Realvalued Features4     0
# Realvalued Features5     0
# Realvalued Features6     0
# Realvalued Features7     0
# Realvalued Features8     0
# Realvalued Features9     0
# Realvalued Features10    0
# Realvalued Features11    0
# Realvalued Features12    0
# Realvalued Features13    0
# Realvalued Features14    0
# Realvalued Features15    0
# Realvalued Features16    0
# Realvalued Features17    0
# Realvalued Features18    0
# Realvalued Features19    0
# Realvalued Features20    0
# Realvalued Features21    0
# Realvalued Features22    0
# Radius                   0
# Texture                  0
# Perimeter                0
# Area                     0
# Smoothness               0
# Compactness              0
# Concavity                0
# Concave Points           0
# Symmetry                 0
# ...

# %%
wpbc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 35 columns):
# ID Number                197 non-null int64
# Outcome                  197 non-null object
# Time                     197 non-null int64
# Realvalued Features1     197 non-null float64
# Realvalued Features2     197 non-null float64
# Realvalued Features3     197 non-null float64
# Realvalued Features4     197 non-null float64
# Realvalued Features5     197 non-null float64
# Realvalued Features6     197 non-null float64
# Realvalued Features7     197 non-null float64
# Realvalued Features8     197 non-null float64
# Realvalued Features9     197 non-null float64
# Realvalued Features10    197 non-null float64
# Realvalued Features11    197 non-null float64
# Realvalued Features12    197 non-null float64
# Realvalued Features13    197 non-null float64
# Realvalued Features14    197 non-null float64
# Realvalued Features15    197 non-null float64
# ...

# %%
# Converting Yes to 1 and No to 0
wpbc_data['Outcome'] = wpbc_data['Outcome'].map({'N': 1, 'R': 0})

# %%
wpbc_data.head()
# Out:
#    ID Number  Outcome  Time  Realvalued Features1  Realvalued Features2  \
# 0       8423        1    61                 17.99                 10.38
# 1     842517        1   116                 21.37                 17.44
# 2     843483        1   123                 11.42                 20.38
# 3     843584        0    27                 20.29                 14.34
# 4     843786        0    77                 12.75                 15.29
#
#    Realvalued Features3  Realvalued Features4  Realvalued Features5  \
# 0                122.80                1001.0               0.11840
# 1                137.50                1373.0               0.08836
# 2                 77.58                 386.1               0.14250
# 3                135.10                1297.0               0.10030
# 4                 84.60                 502.7               0.11890
#
#    Realvalued Features6  Realvalued Features7        ...          Radius  \
# ...

# %% [markdown]
# ### Check the different attribute and rate to probability of diesease

# %%
Concavity = (sum(wpbc_data['Concavity'])/len(wpbc_data['Concavity'].index))*100
Concavity
# Out:
# 32.36868020304567

# %%
Radius = (sum(wpbc_data['Radius'])/len(wpbc_data['Radius'].index))*100
Radius
# Out:
# 14035.106598984768

# %%
ConcavePoints = (sum(wpbc_data['Concave Points'])/len(wpbc_data['Concave Points'].index))*100
ConcavePoints
# Out:
# 9.087736040609135

# %%
Compactness = (sum(wpbc_data['Compactness'])/len(wpbc_data['Compactness'].index))*100
Compactness
# Out:
# 17.909111675126912

# %%
Area = (sum(wpbc_data['Area'])/len(wpbc_data['Area'].index))*100
Area
# Out:
# 36.59774619289336

# %%
smoothness = (sum(wpbc_data['Smoothness'])/len(wpbc_data['Smoothness'].index))*100
smoothness
# Out:
# 43.730807106598974

# %%
perimeter = (sum(wpbc_data['Perimeter'])/len(wpbc_data['Perimeter'].index))*100
perimeter
# Out:
# 14.404472081218266

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### Splitting Data into Training and Test Sets

# %%
from sklearn.model_selection import train_test_split

# Putting feature variable to X
X = wpbc_data.drop(['Outcome','ID Number'],axis=1)

# Putting response variable to y
y = wpbc_data['Outcome']

y.head()
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    0.0
# 4    0.0
# Name: Outcome, dtype: float64

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
# Converting String (?) to float
wpbc_data = wpbc_data.replace('?', regex=True).astype(float)

# %% [markdown]
# ### Correlation Matrix

# %%
# Importing matplotlib and seaborn
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Let's see the correlation matrix 
plt.figure(figsize = (20,10))        # Size of the figure
sns.heatmap(wpbc_data.corr(),annot = True)

# %%
# Special charaters, is handled with the space.
##removeSpecialChars = wpbc_data.replace ({ord(c): 0.00 for c in '?'})

# %% [markdown]
# ### Dropping highly corelated observation

# %%
X_test2 = X_test.drop(['Realvalued Features1','Realvalued Features3','Realvalued Features4','Realvalued Features7','Realvalued Features8','Realvalued Features13','Realvalued Features14','Realvalued Features21','Realvalued Features22','Radius','Texture'],1)
X_train2 = X_train.drop(['Realvalued Features1','Realvalued Features3','Realvalued Features4','Realvalued Features7','Realvalued Features8','Realvalued Features13','Realvalued Features14','Realvalued Features21','Realvalued Features22','Radius','Texture'],1)

# %% [markdown]
# #### Checking the Correlation Matrix

# %% [markdown]
# ##### After dropping highly correlated variables now let's check the correlation matrix again.

# %%
plt.figure(figsize = (20,10))
sns.heatmap(X_train2.corr(),annot = True)

# %% [markdown]
# ### Random Forest

# %%
# Importing random forest classifier from sklearn library
from sklearn.ensemble import RandomForestClassifier

# Running the random forest with default parameters.
rfc = RandomForestClassifier()

# %%
# fit
rfc.fit(X_train2,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# Making predictions
predictions = rfc.predict(X_test2)

# %%
# Importing classification report and confusion matrix from sklearn metrics
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

# %%
# Let's check the report of our default model
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.55      0.29      0.37        21
#         1.0       0.69      0.87      0.77        39
#
# avg / total       0.64      0.67      0.63        60

# %%
# Printing confusion matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 6 15]
#  [ 5 34]]

# %%
print(accuracy_score(y_test,predictions))
# Out:
# 0.6666666666666666

# %% [markdown]
# ### Hyperparameter Tuning

# %% [markdown]
# #### Tuning max_depth

# %%
## Let's try to find the optimum values for max_depth and understand how the value of max_depth impacts the overall accuracy of the ensemble.

# GridSearchCV to find optimal n_estimators
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'max_depth': range(2, 20, 5)}

# instantiate the model
rf = RandomForestClassifier()


# fit tree on training data
rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
rf.fit(X_train2, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': range(2, 20, 5)}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring='accuracy',
#        verbose=0)

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
# plotting accuracies with max_depth
plt.figure()
plt.plot(scores["param_max_depth"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_max_depth"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("max_depth")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %% [markdown]
# ### Tuning n_estimators

# %%
# GridSearchCV to find optimal n_estimators
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'n_estimators': range(100, 1500, 400)}

# instantiate the model (note we are specifying a max_depth)
rf = RandomForestClassifier(max_depth=4)


# fit tree on training data
rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
rf.fit(X_train2, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': range(100, 1500, 400)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
# plotting accuracies with n_estimators
plt.figure()
plt.plot(scores["param_n_estimators"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_n_estimators"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("n_estimators")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %% [markdown]
# #### Tuning max_features
# how the model performance varies with max_features, which is the maximum numbre of features considered for splitting at a node.

# %%
# GridSearchCV to find optimal max_features
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'max_features': [4, 8, 14, 20, 24]}

# instantiate the model
rf = RandomForestClassifier(max_depth=4)


# fit tree on training data
rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_features': [4, 8, 14, 20, 24]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
# plotting accuracies with max_features
plt.figure()
plt.plot(scores["param_max_features"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_max_features"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("max_features")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Tuning min_samples_leaf

# %%
# GridSearchCV to find optimal min_samples_leaf
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'min_samples_leaf': range(100, 400, 50)}

# instantiate the model
rf = RandomForestClassifier()


# fit tree on training data
rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'min_samples_leaf': range(100, 400, 50)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
# plotting accuracies with min_samples_leaf
plt.figure()
plt.plot(scores["param_min_samples_leaf"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_min_samples_leaf"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("min_samples_leaf")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Tuning min_samples_split
# Let's now look at the performance of the ensemble as we vary min_samples_split.

# %%
# GridSearchCV to find optimal min_samples_split
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV


# specify number of folds for k-fold CV
n_folds = 5

# parameters to build the model on
parameters = {'min_samples_split': range(200, 500, 50)}

# instantiate the model
rf = RandomForestClassifier()


# fit tree on training data
rf = GridSearchCV(rf, parameters, 
                    cv=n_folds, 
                   scoring="accuracy")
rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'min_samples_split': range(200, 500, 50)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# scores of GridSearch CV
scores = rf.cv_results_
pd.DataFrame(scores).head()
# Out:
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...

# %%
# plotting accuracies with min_samples_split
plt.figure()
plt.plot(scores["param_min_samples_split"], 
         scores["mean_train_score"], 
         label="training accuracy")
plt.plot(scores["param_min_samples_split"], 
         scores["mean_test_score"], 
         label="test accuracy")
plt.xlabel("min_samples_split")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# C:\PY\lib\site-packages\sklearn\utils\deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# ### Grid Search to Find Optimal Hyperparameters
# We can now find the optimal hyperparameters using GridSearchCV

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'max_depth': [4,8,10],
    'min_samples_leaf': range(100, 400, 200),
    'min_samples_split': range(200, 500, 200),
    'n_estimators': [100,200, 300], 
    'max_features': [5, 10]
}
# Create a based model
rf = RandomForestClassifier()
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1,verbose = 1)

# %%
# Fit the grid search to the data
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   46.7s
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:   50.6s finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'max_depth': [4, 8, 10], 'min_samples_leaf': range(100, 400, 200), 'min_samples_split': range(200, 500, 200), 'n_estimators': [100, 200, 300], 'max_features': [5, 10]},
# ...

# %% [markdown]
# #### Fitting the final model with the best parameters obtained from grid search.

# %%
# model with the best hyperparameters
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(bootstrap=True,
                             max_depth=10,
                             min_samples_leaf=100, 
                             min_samples_split=200,
                             max_features=10,
                             n_estimators=100)

# %%
# fit
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features=10, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=100, min_samples_split=200,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# predict
predictions = rfc.predict(X_test)

# %%
# evaluation metrics
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#              precision    recall  f1-score   support
#
#         0.0       0.00      0.00      0.00        21
#         1.0       0.65      1.00      0.79        39
#
# avg / total       0.42      0.65      0.51        60
# C:\PY\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[ 0 21]
#  [ 0 39]]

# %%
# printing the optimal accuracy score and hyperparameters
print('We can get accuracy of',grid_search.best_score_,'using',grid_search.best_params_)
# Out:
# We can get accuracy of 0.8102189781021898 using {'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 100, 'min_samples_split': 200, 'n_estimators': 100}

# %% [markdown]
# ## Logistic Regression

# %%
logm2 = sm.GLM(y_train,(sm.add_constant(X_train2)), family = sm.families.Binomial())
logm2.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                Outcome   No. Observations:                  137
# Model:                            GLM   Df Residuals:                      114
# Model Family:                Binomial   Df Model:                           22
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -38.756
# Date:                Fri, 13 Nov 2020   Deviance:                       77.513
# Time:                        14:35:17   Pearson chi2:                     114.
# No. Iterations:                     7
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                   -10.1152      7.001     -1.445      0.149     -23.838       3.607
# ...

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
from sklearn.feature_selection import RFE
rfe = RFE(logreg, 13)             # running RFE with 13 variables as output
rfe = rfe.fit(X,y)
print(rfe.support_)           # Printing the boolean results
print(rfe.ranking_)           # Printing the ranking
# Out:
# [False  True  True False False  True False False False  True False False
#   True False False False False False False False False  True False False
#  False  True  True  True  True False  True  True  True]
# [ 4  1  1 19 20  1  5 13  8  1 18  3  1  6 10 14 11  2 12 17 16  1 15  9
#  21  1  1  1  1  7  1  1  1]

# %%
# Let's run the model using the selected variables
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logsk = LogisticRegression(C=1e9)
#logsk.fit(X_train[col], y_train)
logsk.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1000000000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
logm4 = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
modres = logm4.fit()
logm4.fit().summary()
# Out:
# C:\PY\lib\site-packages\statsmodels\genmod\families\family.py:1003: RuntimeWarning: divide by zero encountered in true_divide
#   return scale * np.sum((endog * np.log(mu/(1 - mu) + 1e-200) +
# C:\PY\lib\site-packages\statsmodels\genmod\families\family.py:1004: RuntimeWarning: divide by zero encountered in log
#   np.log(1 - mu)) * freq_weights)
# C:\PY\lib\site-packages\statsmodels\genmod\families\family.py:1004: RuntimeWarning: invalid value encountered in add
#   np.log(1 - mu)) * freq_weights)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                Outcome   No. Observations:                  137
# Model:                            GLM   Df Residuals:                      103
# Model Family:                Binomial   Df Model:                           33
# Link Function:                  logit   Scale:                             1.0
# ...

# %% [markdown]
# ### Making Predictions

# %%
#Predicted probabilities
y_pred = logsk.predict_proba(X_test)
# Converting y_pred to a dataframe which is an array
y_pred_df = pd.DataFrame(y_pred)
# Converting to column dataframe
y_pred_1 = y_pred_df.iloc[:,[1]]
# Let's see the head
y_pred_1.head()
# Out:
#           1
# 0  0.010578
# 1  0.342133
# 2  0.066110
# 3  0.850656
# 4  0.848452

# %%
# Converting y_test to dataframe
y_test_df = pd.DataFrame(y_test)
y_test_df.head()
# Out:
#      Outcome
# 74       0.0
# 165      1.0
# 158      0.0
# 189      1.0
# 78       1.0

# %%
# Putting ID Number to index
#y_test_df['ID Number'] = y_test_df.index
# Removing index for both dataframes to append them side by side 
y_pred_1.reset_index(drop=True, inplace=True)
y_test_df.reset_index(drop=True, inplace=True)
# Appending y_test_df and y_pred_1
y_pred_final = pd.concat([y_test_df,y_pred_1],axis=1)
# Renaming the column 
y_pred_final= y_pred_final.rename(columns={ 1 : 'Outcome_Prob'})
# Rearranging the columns
y_pred_final = y_pred_final.reindex_axis(['CustID','Outcome','Outcome_Prob'], axis=1)
# Let's see the head of y_pred_final
y_pred_final.head()
# Out:
# C:\PY\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
#   # This is added back by InteractiveShellApp.init_path()
#    CustID  Outcome  Outcome_Prob
# 0     NaN      0.0      0.010578
# 1     NaN      1.0      0.342133
# 2     NaN      0.0      0.066110
# 3     NaN      1.0      0.850656
# 4     NaN      1.0      0.848452

# %%
# Creating new column 'predicted' with 1 if Churn_Prob>0.5 else 0
y_pred_final['predicted'] = y_pred_final.Outcome_Prob.map( lambda x: 1 if x > 0.5 else 0)
# Let's see the head
y_pred_final.head()
# Out:
#    CustID  Outcome  Outcome_Prob  predicted
# 0     NaN      0.0      0.010578          0
# 1     NaN      1.0      0.342133          0
# 2     NaN      0.0      0.066110          0
# 3     NaN      1.0      0.850656          1
# 4     NaN      1.0      0.848452          1

# %% [markdown]
# #### Model Evaluation

# %%
from sklearn import metrics

# %%
# Confusion matrix 
confusion = metrics.confusion_matrix( y_pred_final.Outcome, y_pred_final.predicted )
confusion
# Out:
# array([[ 8, 13],
#        [ 3, 36]], dtype=int64)

# %%
#Let's check the overall accuracy.
metrics.accuracy_score(y_pred_final.Outcome, y_pred_final.predicted)
# Out:
# 0.7333333333333333

# %%
def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(6, 6))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return fpr, tpr, thresholds

# %%
draw_roc(y_pred_final.Outcome, y_pred_final.predicted)
# Out:
# (array([0.        , 0.61904762, 1.        ]),
#  array([0.        , 0.92307692, 1.        ]),
#  array([2, 1, 0], dtype=int64))

# %%
#draw_roc(y_pred_final.Churn, y_pred_final.predicted)
"{:2.2f}".format(metrics.roc_auc_score(y_pred_final.Outcome, y_pred_final.Outcome_Prob))
# Out:
# '0.65'

# %% [markdown]
# ## PCA on the data

# %% [markdown]
# #### While computng the principal components, we must not include the entire dataset. Model building is all about doing well on the data we haven't seen yet!
# So we'll calculate the PCs using the train data, and apply them later on the test data

# %%
X_train.shape
# Out:
# (137, 33)

# %%
#Improting the PCA module
from sklearn.decomposition import PCA
pca = PCA(svd_solver='randomized', random_state=42)

# %%
#Doing the PCA on the train data
pca.fit(X_train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=42,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %% [markdown]
# Let's plot the principal components and try to make sense of them
# •We'll plot original features on the first 2 principal components as axes

# %%
pca.components_
# Out:
# array([[-1.66805044e-02,  4.50462817e-03,  1.01326020e-03, ...,
#         -1.22637080e-05,  1.84015776e-04, -5.29741065e-04],
#        [ 8.28084594e-02, -8.68196667e-03, -6.79377088e-03, ...,
#          7.34183197e-05, -5.00374789e-04, -2.17725607e-03],
#        [ 9.94513509e-01,  1.40549839e-03, -3.28158872e-02, ...,
#          9.02667244e-05, -5.75975549e-03, -1.29379188e-02],
#        ...,
#        [-5.68585603e-07, -5.26652679e-03,  8.64456232e-06, ...,
#         -1.69538541e-01, -3.40083823e-05,  1.90075848e-05],
#        [-6.96339844e-06,  2.50796597e-03, -6.44333827e-05, ...,
#         -3.17798374e-03, -6.37631722e-05,  2.69680745e-06],
#        [ 1.94513805e-06, -5.98566854e-04,  5.92282457e-06, ...,
#         -7.57308716e-02,  6.46306999e-06, -7.51749230e-07]])

# %%
colnames = list(X_train.columns)
pcs_df = pd.DataFrame({'PC1':pca.components_[0],'PC2':pca.components_[1], 'Feature':colnames})
pcs_df.head()
# Out:
#         PC1       PC2               Feature
# 0 -0.016681  0.082808                  Time
# 1  0.004505 -0.008682  Realvalued Features1
# 2  0.001013 -0.006794  Realvalued Features2
# 3  0.030464 -0.057636  Realvalued Features3
# 4  0.506797 -0.855351  Realvalued Features4

# %%
# %matplotlib inline
fig = plt.figure(figsize = (8,8))
plt.scatter(pcs_df.PC1, pcs_df.PC2)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
for i, txt in enumerate(pcs_df.Feature):
    plt.annotate(txt, (pcs_df.PC1[i],pcs_df.PC2[i]))
plt.tight_layout()
plt.show()

# %% [markdown]
# Realvalued feature 14 component is in the direction where the probability can weighted side
# •These 2 components also have the highest of the loadings

# %% [markdown]
# ### Looking at the screeplot to assess the number of needed principal components

# %%
pca.explained_variance_ratio_
# Out:
# array([9.61602685e-01, 3.33825941e-02, 2.66380426e-03, 2.03679616e-03,
#        1.19117462e-04, 1.01503896e-04, 7.13194445e-05, 7.87443209e-06,
#        6.89095526e-06, 5.85780750e-06, 7.33382879e-07, 5.02834147e-07,
#        1.75161007e-07, 9.09495732e-08, 2.87250287e-08, 1.19750068e-08,
#        5.60594910e-09, 3.11290567e-09, 2.25924558e-09, 7.63150463e-10,
#        4.32101220e-10, 3.79089266e-10, 3.35134418e-10, 2.44497506e-10,
#        1.43764566e-10, 8.57960171e-11, 3.24624249e-11, 3.04515735e-11,
#        2.58459577e-11, 7.11721169e-12, 6.12303205e-12, 2.22885516e-12,
#        3.58322643e-13])

# %%
#Making the screeplot - plotting the cumulative variance against the number of components
# %matplotlib inline
fig = plt.figure(figsize = (12,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %% [markdown]
# Looks like 6 components are enough to describe 98% of the variance in the dataset
# •We'll choose 6 components for our modeling

# %%
#Using incremental PCA for efficiency - saves a lot of time on larger datasets
from sklearn.decomposition import IncrementalPCA
pca_final = IncrementalPCA(n_components=6)

# %% [markdown]
# #### Basis transformation - getting the data onto our PCs

# %%
df_train_pca = pca_final.fit_transform(X_train)
df_train_pca.shape
# Out:
# (137, 6)

# %% [markdown]
# ### Creating correlation matrix for the principal components - we expect little to no correlation

# %%
#creating correlation matrix for the principal components
corrmat = np.corrcoef(df_train_pca.transpose())

# %%
#plotting the correlation matrix
# %matplotlib inline
plt.figure(figsize = (20,10))
sns.heatmap(corrmat,annot = True)

# %%
# 1s -> 0s in diagonals
corrmat_nodiag = corrmat - np.diagflat(corrmat.diagonal())
print("max corr:",corrmat_nodiag.max(), ", min corr: ", corrmat_nodiag.min(),)
# we see that correlations are indeed very close to 0
# Out:
# max corr: 5.6030764782593604e-15 , min corr:  -2.653011712847609e-15

# %% [markdown]
# We effectively have removed multicollinearity from our situation, and our models will be much more stable

# %%
#Applying selected components to the test data - 16 components
df_test_pca = pca_final.transform(X_test)
df_test_pca.shape
# Out:
# (60, 6)

# %% [markdown]
#  #### Applying a logistic regression on our Principal Components
# • We expect to get similar model performance with significantly lower features
# • If we can do so, we would have done effective dimensionality reduction without losing any import information

# %%
#Training the model on the train data
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

learner_pca = LogisticRegression()
model_pca = learner_pca.fit(df_train_pca,y_train)

# %% [markdown]
# #### Note
#
# Note that we are fitting the original variable y with the transformed variables (principal components). This is not a problem becuase the transformation done in PCA is linear, which implies that you've only changed the way the new x variables are represented, though the nature of relationship between X and Y is still linear.

# %%
#Making prediction on the test data
pred_probs_test = model_pca.predict_proba(df_test_pca)[:,1]
"{:2.2}".format(metrics.roc_auc_score(y_test, pred_probs_test))
# Out:
# '0.74'

# %% [markdown]
# #### let PCA select the number of components basen on a variance cutoff we provide

# %%
pca_again = PCA(0.90)

# %%
df_train_pca2 = pca_again.fit_transform(X_train)
df_train_pca2.shape
# Out:
# (137, 1)

# %%
#training the regression model
learner_pca2 = LogisticRegression()
model_pca2 = learner_pca2.fit(df_train_pca2,y_train)

# %%
df_test_pca2 = pca_again.transform(X_test)
df_test_pca2.shape
# Out:
# (60, 1)

# %%
#Making prediction on the test data
pred_probs_test2 = model_pca2.predict_proba(df_test_pca2)[:,1]
"{:2.2f}".format(metrics.roc_auc_score(y_test, pred_probs_test2))
# Out:
# '0.58'

# %% [markdown]
# #### Let's Visualize

# %%
# %matplotlib inline
fig = plt.figure(figsize = (8,8))
plt.scatter(df_train_pca[:,0], df_train_pca[:,1], c = y_train.map({0:'green',1:'red'}))
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.tight_layout()
plt.show()

# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(8,8))
ax = Axes3D(fig)
# ax = plt.axes(projection='3d')
ax.scatter(df_train_pca[:,2], df_train_pca[:,0], df_train_pca[:,1], c=y_train.map({0:'green',1:'red'}))
# Out:
# <img src="data:image/png;base64,..." width="576">
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# #### try building the model with just 3 principal components

# %%
pca_last = PCA(n_components=3)
df_train_pca3 = pca_last.fit_transform(X_train)
df_test_pca3 = pca_last.transform(X_test)
df_test_pca3.shape
# Out:
# (60, 3)

# %%
#training the regression model
learner_pca3 = LogisticRegression()
model_pca3 = learner_pca3.fit(df_train_pca3,y_train)
#Making prediction on the test data
pred_probs_test3 = model_pca3.predict_proba(df_test_pca3)[:,1]
"{:2.2f}".format(metrics.roc_auc_score(y_test, pred_probs_test3))
# Out:
# '0.80'

# %% [markdown]
# #### Achieved Good score
